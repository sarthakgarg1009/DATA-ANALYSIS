# %%
import pandas as pd
from pandas import Series

import numpy as np

import matplotlib.pyplot as mpl

import seaborn as sns

# %matplotlib inline

# %%
titanic = pd.read_csv(r'd:\train.csv')

# %%
titanic_df = pd.DataFrame(titanic)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
# Q1. WHAT ALL THE PASSENEGR WERRE THERE ON TITANIC

# %%
# sperate by gender
sns.factorplot('Sex',data=titanic_df,kind='count')
# Out:
# C:\Users\user\Anaconda2\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Sex',kind='count')

# %%
#classification of child and aged 

def male_female_child(passenger):
    age,sex = passenger
    
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['Person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Person',kind='count')

# %%
titanic_df['Age'].hist(bins=100)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['Person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: Person, dtype: int64

# %%
# FacetGrid allowes multiple plot
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)

fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

#LEGENDS ARE GIVEN TO SHOW WHICH LINE COLOR IS REPRESENTING WHICH DATA
fig.add_legend()

# %%
fig=sns.FacetGrid(titanic_df,hue='Person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest=titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
#Q2. What deck were the passenger on and how does that relate to their class?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
level = []

for levels in deck:
    level.append(levels[0])

cabin_df = pd.DataFrame(level)

cabin_df.columns = ['Cabins']
    
sns.factorplot('Cabins',data=cabin_df,kind='count',palette='summer')

# %%
cabin_df=cabin_df[cabin_df.Cabins != 'T']
sns.factorplot('Cabins',data=cabin_df,kind='count',palette='winter')

# %%
#Q3. From where did the people come from

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
sns.factorplot('Embarked',data=titanic_df,kind='count',palette='winter',hue='Pclass')

# %%
#Q4. Who was alone or who was with family?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Alone'] = titanic_df.Parch + titanic_df.SibSp

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone'] >0] = 'With family'
titanic_df['Alone'].loc[titanic_df['Alone'] ==0]= 'Without family'
# Out:
# C:\Users\user\Anaconda2\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.factorplot('Alone',data=titanic_df,kind='count')

# %%
#Q5. What factor helped someone survive the sinking?

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0:'no',1:'Yes'})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person           Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male     With family
# 1      0          PC 17599  71.2833   C85        C  female     With family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  Without family
# ...

# %%
sns.factorplot('Survivor',data=titanic_df,palette='Set1',kind='count')

# %%
sns.factorplot('Survivor',data=titanic_df,hue='Pclass',kind='count')

# %%
sns.factorplot('Pclass','Survivor',data=titanic_df,hue='Person')

# %%
sns.lmplot('Age','Survived',data=titanic_df,hue='Person')

# %%
generation= [10,20,30,40,50,60,80,90]

sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,x_bins=generation)

# %%
sns.lmplot('Age','Survived',hue='Sex',data=titanic_df,palette='winter',x_bins=generation)

# %%
#Q6. Did the deck have an effect on pessengers survival rate?

# %%
a=titanic_df[['Survived','Cabin']]

# %%
a
# Out:
#      Survived        Cabin
# 0           0          NaN
# 1           1          C85
# 2           1          NaN
# 3           1         C123
# 4           0          NaN
# 5           0          NaN
# 6           0          E46
# 7           0          NaN
# 8           1          NaN
# 9           1          NaN
# 10          1           G6
# 11          1         C103
# 12          0          NaN
# 13          0          NaN
# 14          0          NaN
# 15          1          NaN
# 16          0          NaN
# 17          1          NaN
# 18          0          NaN
# 19          1          NaN
# 20          0          NaN
# 21          1          D56
# 22          1          NaN
# 23          1           A6
# 24          0          NaN
# 25          1          NaN
# 26          0          NaN
# 27          0  C23 C25 C27
# 28          1          NaN
# 29          0          NaN
# ..        ...          ...
# 861         0          NaN
# 862         1          D17
# ...

# %%
ab=a.dropna()

# %%
ab = d['Cabin']
b=ab[0]

# %%
# Q7 DID HAVING THE FAMILY MEMBER INCEASE THE CHANCE TO BE ALIVE?

# %%
sns.factorplot('Survivor',data=titanic_df,kind='count',hue='Alone')
